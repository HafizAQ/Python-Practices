# %% [markdown]
# <a href="https://colab.research.google.com/github/HafizAQ/Python-Practices/blob/main/blockchain_python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Courtesy:** https://www.youtube.com/watch?v=b81Ib_oYbFk

# %%
import datetime
import hashlib

# %%
class Block:
    blockNo = 0
    data = None
    next = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()

    def __init__(self, data):
        self.data = data

    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()

    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) + "\nBlock Data: " + str(self.data) + "\nHashes: " + str(self.nonce) + "\n--------------"

class Blockchain:

    diff = 20
    maxNonce = 2**32
    target = 2 ** (256-diff)

    block = Block("Genesis")
    dummy = head = block

    def add(self, block):

        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1

        self.block.next = block
        self.block = self.block.next

    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1

blockchain = Blockchain()

for n in range(10):
    blockchain.mine(Block("Block " + str(n+1)))
    print()
print(blockchain)

while blockchain.head != None:
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: 8f7dd0fc40bfea32b06a3d79e3e1611ef8da1b6f1a070343c865a5655c9bbd88
# BlockNo: 1
# Block Data: Block 1
# Hashes: 197150
# --------------
#
# Block Hash: 7047c37dfcfabf2d483d44043e49294bac8a6817fa9228edc81c1d8018ac5cc9
# BlockNo: 2
# Block Data: Block 2
# Hashes: 2076227
# --------------
#
# Block Hash: 8de8274d7a058a4cfb586968e5822f382313364d181e83051f198494f3c59804
# BlockNo: 3
# Block Data: Block 3
# Hashes: 1442061
# --------------
#
# Block Hash: 32bbe9bcb1859d89a2f27d30c54f138464a87497bc86cd4e3da3cbc02b2de31b
# BlockNo: 4
# Block Data: Block 4
# Hashes: 796306
# --------------
#
# Block Hash: 067be64f5e4dcbd48e075d682dace68f7fbfb67b8c6be9467bc3e785ff580189
# BlockNo: 5
# Block Data: Block 5
# Hashes: 2457561
# --------------
#
# Block Hash: b3fadcfedadf5892590215ab5e96fac08bfd23a8932dff8b46262b61f31220b6
# BlockNo: 6
# Block Data: Block 6
# Hashes: 1229625
# --------------
#
# Block Hash: 5c26adce328608205fdb1ef03656f26ebbf64b130ed26fb9581794ce64e3d6ee
# BlockNo: 7
# ...
