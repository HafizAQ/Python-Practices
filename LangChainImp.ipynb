# %% [markdown]
# <a href="https://colab.research.google.com/github/HafizAQ/Python-Practices/blob/main/LangChainImp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.9/273.9 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.3
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.6.0
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.14.0
# ...

# %%
#Langchain provides facilitation to the diverse i) datasources ii) model providers iii) the like
#Tailorable prompts to meet specific needs + guide context for enhanced precision + integrating models (components and vector sources)
#Install all dependancies
# !pip install langchain[all]

# %%
#For OpenAI- GPT4 API
# API_KEY ="..."
# from langchain.llms import OpenAI
# llm = OpenAI(model_name="text-ada-001", openai_api_key=API_KEY)
# print(llm("Tell me a joke about data scientist"))

#Models from HuggingFace

API_KEY ="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"   #Access Tokens

from langchain import HuggingFaceHub  #use of hugging face models using Langchains

llm = HuggingFaceHub(repo_id = "google/flan-t5-base", huggingfacehub_api_token = API_KEY)

print(llm("Tell me a joke about scientist"))
# Out:
# a scientist is a scientist

# %%
#multiple prompts

llm_response = llm.generate(['Tell me a joke about data scientist', 'Tell me a joke about recruiter', 'Tell me a joke about psychologist'])

# %%
llm_response.generations[0]
# Out:
# [Generation(text="if you're a data scientist, you're a data scientist.")]

# %%
llm_response.generations[1]
# Out:
# [Generation(text="i'm a recruiter")]

# %%
llm_response.generations[2]
# Out:
# [Generation(text='a psychologist is a person who is a psychologist.')]

# %%
#Managing Prompt templates for LLMs in LangChain=> templating to generate prompts. Useful, when we use same prompt outline in multiple places but with certain value changed
# USER_INPUT = 'Paris'
# from langchain.llms import OpenAI
# from langchain import PromptTemplate
# llm = OpenAI(model_name="text-davinci-003", openai_api_key=API_KEY)
# template = """ I am travelling to {location}. What are the top 3 things I can do while I am there. Be very specific and respond as three bullet points """
# prompt = PromptTemplate(input_variables=["location"],template=template,)
# final_prompt = prompt.format(location=USER_INPUT )
# print(f"LLM Output: {llm(final_prompt)}")


#I use with hugging faced model
#gpt 2
#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
API_KEY="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"
# USER_INPUT = 'Paris'
USER_INPUT = 'London'
# from langchain.llms import OpenAI
from langchain import HuggingFaceHub
from langchain import PromptTemplate
# llm = OpenAI(model_name="gpt2", openai_api_key=API_KEY)
llm = HuggingFaceHub(repo_id="gpt2", huggingfacehub_api_token=API_KEY)
template = """ I am travelling to {location}. What are the top 3 things I can do while I am there. Be very specific and respond as three bullet points """
prompt = PromptTemplate(input_variables=["location"],
                        template=template,)
final_prompt = prompt.format(location=USER_INPUT )
print(f"LLM Output: {llm(final_prompt)}")
# Out:
# LLM Output:  I am travelling to London. What are the top 3 things I can do while I am there. Be very specific and respond as three bullet points  can be very relevant for you. 1). Your career. Your job as a journalist. What

# %%
#Combining LLMs with Multi-step workflows
#1) Sequencially combining multiple LLMs by using output of the first LLM as input for the second LLM
#2) Integrating LLMs with prompt templates
#3) Merging LLMs with external data, such as for question answering (RAG-LLM: Retrival Augumentation Generation)
#4) Incorporating LLMs with long-term memory, like chat history

# from langchain.llms import OpenAI
# from langchain.chains import LLMChain, SimpleSequentialChain
# from langchain import PromptTemplate
# llm = OpenAI(model_name="text-davinci-003", openai_api_key=API_KEY)
# # first step in chain
# template = "What is the most popular city in {country} for tourists? Just return the name of the city"
# first_prompt = PromptTemplate(input_variables=["country"],template=template)
# chain_one = LLMChain(llm = llm, prompt = first_prompt)
# # second step in chain
# second_prompt = PromptTemplate(input_variables=["city"],template="What are the top three things to do in this: {city} for tourists. Just return the answer as three bullet points.",)
# chain_two = LLMChain(llm=llm, prompt=second_prompt)
# # Combine the first and the second chain
# overall_chain = SimpleSequentialChain(chains=[chain_one, chain_two], verbose=True)
# final_answer = overall_chain.run("Canada")


#Apply with Hugging face API support
API_KEY ="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"   #Access Tokens
from langchain import HuggingFaceHub  #use of hugging face models using Langchains
from langchain.chains import LLMChain, SimpleSequentialChain #chain of LLM models in parallel, also in sequuential oder chains
from langchain import PromptTemplate #prompt template library
llm = HuggingFaceHub(repo_id = "google/flan-t5-base", huggingfacehub_api_token = API_KEY)
# google/flan-t5-base
# first step in chain
template = "What is the most popular city in {country} for tourists? Just return the name of the city"

first_prompt = PromptTemplate(input_variables=["country"],template=template)

chain_one = LLMChain(llm = llm, prompt = first_prompt)

# second step in chain
second_prompt = PromptTemplate(input_variables=["city"],template="What are the top three things to do in this: {city} for tourists. Just return the answer as three bullet points.",)

chain_two = LLMChain(llm=llm, prompt=second_prompt)

# Combine the first and the second chain
overall_chain = SimpleSequentialChain(chains=[chain_one, chain_two], verbose=True)

final_answer = overall_chain.run("USA")
# Out:
# > Entering new SimpleSequentialChain chain...
# san francisco
# San Francisco is a great place to visit
#
# > Finished chain.
